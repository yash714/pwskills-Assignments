# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df['Pregnancies'][df['Pregnancies']==0]=df['Pregnancies'].mean()
# Out:
# /tmp/ipykernel_77/382244621.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pregnancies'][df['Pregnancies']==0]=df['Pregnancies'].mean()

# %%
df['Pregnancies'][df['Pregnancies']==0]
# Out:
# Series([], Name: Pregnancies, dtype: float64)

# %%
df['Glucose'][df['Glucose']==0]=df['Glucose'].mean()
df['BloodPressure'][df['BloodPressure']==0]=df['BloodPressure'].mean()
df['SkinThickness'][df['SkinThickness']==0]=df['SkinThickness'].mean()
df['Insulin'][df['Insulin']==0]=df['Insulin'].mean()
df['BMI'][df['BMI']==0]=df['BMI'].mean()
# Out:
# /tmp/ipykernel_77/3721914126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Glucose'][df['Glucose']==0]=df['Glucose'].mean()
# /tmp/ipykernel_77/3721914126.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BloodPressure'][df['BloodPressure']==0]=df['BloodPressure'].mean()
# /tmp/ipykernel_77/3721914126.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      4.400782  121.681605      72.254807      26.606479  118.660163
# std       2.984162   30.436016      12.115932       9.631241   93.080358
# min       1.000000   44.000000      24.000000       7.000000   14.000000
# 25%       2.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.845052  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# ...

# %%
for i in ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']:
    df[i][df[i]==0]=df[i].mean()
# Out:
# /tmp/ipykernel_77/3213915945.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i][df[i]==0]=df[i].mean()

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.boxplot(data=df, width= 0.5,ax=ax,  fliersize=3)
# Out:
# <AxesSubplot: >

# %%
def remove_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1
    upper_limit = Q3 + 1.5 * IQR
    lower_limit = Q1 - 1.5 * IQR
    return column[(column > lower_limit) & (column < upper_limit)]

# Remove outliers from all columns using the defined function
df_clean = df.apply(remove_outliers)

# Drop any rows with missing values
df_clean.dropna(inplace=True)

# %%
#Independent and dependent features
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x,y
# Out:
# (     Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
#  0       6.000000    148.0           72.0      35.000000   79.799479  33.6
#  1       1.000000     85.0           66.0      29.000000   79.799479  26.6
#  2       8.000000    183.0           64.0      20.536458   79.799479  23.3
#  3       1.000000     89.0           66.0      23.000000   94.000000  28.1
#  4       3.845052    137.0           40.0      35.000000  168.000000  43.1
#  ..           ...      ...            ...            ...         ...   ...
#  763    10.000000    101.0           76.0      48.000000  180.000000  32.9
#  764     2.000000    122.0           70.0      27.000000   79.799479  36.8
#  765     5.000000    121.0           72.0      23.000000  112.000000  26.2
#  766     1.000000    126.0           60.0      20.536458   79.799479  30.1
#  767     1.000000     93.0           70.0      31.000000   79.799479  30.4
#
#       DiabetesPedigreeFunction  Age
# ...

# %%
       ### train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
     X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
## Post Pruning
treeclassifier=DecisionTreeClassifier()

# %%
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treeclassifier,filled=True)
# Out:
# [Text(0.6540050287356322, 0.9705882352941176, 'x[1] <= 154.5\ngini = 0.457\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.3942169540229885, 0.9117647058823529, 'x[7] <= 30.5\ngini = 0.382\nsamples = 432\nvalue = [321, 111]'),
#  Text(0.24209770114942528, 0.8529411764705882, 'x[1] <= 127.5\ngini = 0.24\nsamples = 251\nvalue = [216, 35]'),
#  Text(0.11925287356321838, 0.7941176470588235, 'x[5] <= 45.45\ngini = 0.153\nsamples = 203\nvalue = [186, 17]'),
#  Text(0.10775862068965517, 0.7352941176470589, 'x[0] <= 6.5\ngini = 0.13\nsamples = 200\nvalue = [186, 14]'),
#  Text(0.09626436781609195, 0.6764705882352942, 'x[1] <= 104.5\ngini = 0.122\nsamples = 199\nvalue = [186, 13]'),
#  Text(0.04597701149425287, 0.6176470588235294, 'x[4] <= 156.0\ngini = 0.037\nsamples = 105\nvalue = [103, 2]'),
#  Text(0.022988505747126436, 0.5588235294117647, 'x[3] <= 41.0\ngini = 0.019\nsamples = 102\nvalue = [101, 1]'),
#  Text(0.011494252873563218, 0.5, 'gini = 0.0\nsamples = 95\nvalue = [95, 0]'),
# ...

# %%
## Post Pruning with max_depth =2
treeclassifier=DecisionTreeClassifier(criterion='entropy',max_depth=2)
treeclassifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treeclassifier,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= 154.5\nentropy = 0.938\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.25, 0.5, 'x[5] <= 26.35\nentropy = 0.822\nsamples = 432\nvalue = [321, 111]'),
#  Text(0.125, 0.16666666666666666, 'entropy = 0.191\nsamples = 102\nvalue = [99, 3]'),
#  Text(0.375, 0.16666666666666666, 'entropy = 0.912\nsamples = 330\nvalue = [222, 108]'),
#  Text(0.75, 0.5, 'x[5] <= 28.7\nentropy = 0.569\nsamples = 82\nvalue = [11, 71]'),
#  Text(0.625, 0.16666666666666666, 'entropy = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.875, 0.16666666666666666, 'entropy = 0.422\nsamples = 70\nvalue = [6, 64]')]

# %%
## prediction 
y_pred=treeclassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(y_pred,y_test)
print(score)
print(classification_report(y_pred,y_test))
# Out:
# 0.7165354330708661
#               precision    recall  f1-score   support
#
#            0       0.92      0.72      0.81       214
#            1       0.31      0.68      0.43        40
#
#     accuracy                           0.72       254
#    macro avg       0.62      0.70      0.62       254
# weighted avg       0.83      0.72      0.75       254

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
parameter={
 'criterion':['gini','entropy','log_loss'],
  'splitter':['best','random'],
  'max_depth':[1,2,3,4,5],
  'max_features':['auto', 'sqrt', 'log2']
    
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
treeclassifier=DecisionTreeClassifier()
clf=GridSearchCV(treeclassifier,param_grid=parameter,cv=5,scoring='accuracy')

# %%
## Train the data
clf.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
clf.best_params_
# Out:
# {'criterion': 'log_loss',
#  'max_depth': 4,
#  'max_features': 'log2',
#  'splitter': 'best'}

# %%
y_pred=clf.predict(X_test)

# %%
score=accuracy_score(y_pred,y_test)

# %%
score
# Out:
# 0.6968503937007874

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.85      0.74       131
#            1       0.77      0.54      0.63       123
#
#     accuracy                           0.70       254
#    macro avg       0.71      0.69      0.69       254
# weighted avg       0.71      0.70      0.69       254
